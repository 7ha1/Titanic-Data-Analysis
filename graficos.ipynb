# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a2330462-d6dd-4c0f-8a5b-683edbc58898" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2330462-d6dd-4c0f-8a5b-683edbc58898">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv('cleaned_dataset.csv')  # Substitua pelo nome correto do seu arquivo

# %%
print(data.head())
# Out:
#    Passengerid   Age     Fare  Sex  sibsp  Parch  Pclass  Embarked  2urvived
# 0            1  22.0   7.2500    0      1      0       3       2.0         0
# 1            2  38.0  71.2833    1      1      0       1       0.0         1
# 2            3  26.0   7.9250    1      0      0       3       2.0         1
# 3            4  35.0  53.1000    1      1      0       1       2.0         1
# 4            5  35.0   8.0500    0      0      0       3       2.0         0

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Passengerid  1309 non-null   int64
#  1   Age          1309 non-null   float64
#  2   Fare         1309 non-null   float64
#  3   Sex          1309 non-null   int64
#  4   sibsp        1309 non-null   int64
#  5   Parch        1309 non-null   int64
#  6   Pclass       1309 non-null   int64
#  7   Embarked     1309 non-null   float64
#  8   2urvived     1309 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 92.2 KB
# None

# %%
print(data.describe())
# Out:
#        Passengerid          Age         Fare          Sex        sibsp  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    29.503186    33.281086     0.355997     0.498854
# std     378.020061    12.905241    51.741500     0.478997     1.041658
# min       1.000000     0.170000     0.000000     0.000000     0.000000
# 25%     328.000000    22.000000     7.895800     0.000000     0.000000
# 50%     655.000000    28.000000    14.454200     0.000000     0.000000
# 75%     982.000000    35.000000    31.275000     1.000000     1.000000
# max    1309.000000    80.000000   512.329200     1.000000     8.000000
#
#              Parch       Pclass     Embarked     2urvived
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean      0.385027     2.294882     1.493506     0.261268
# std       0.865560     0.837836     0.814244     0.439494
# min       0.000000     1.000000     0.000000     0.000000
# ...

# %%
print(data.isnull().sum())
# Out:
# Passengerid    0
# Age            0
# Fare           0
# Sex            0
# sibsp          0
# Parch          0
# Pclass         0
# Embarked       0
# 2urvived       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

data['Pclass'].value_counts().plot(kind='bar', color=['blue', 'green', 'red'])
plt.title('Distribuição de Passageiros por Classe')
plt.xlabel('Classe')
plt.ylabel('Número de Passageiros')
plt.show()

# %%
plt.plot(data['Age'], data['Fare'], 'o', color='purple', alpha=0.5)
plt.title('Idade vs. Tarifa')
plt.xlabel('Idade')
plt.ylabel('Tarifa')
plt.show()

# %%
data['Age'].plot(kind='hist', bins=20, color='orange', edgecolor='black')
plt.title('Distribuição de Idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

# %%
import seaborn as sns

sns.countplot(x='Sex', hue='2urvived', data=data, palette='coolwarm')
plt.title('Sobrevivência por Sexo')
plt.xlabel('Sexo (0=Homem, 1=Mulher)')
plt.ylabel('Número de Passageiros')
plt.legend(['Não Sobreviveu', 'Sobreviveu'])
plt.show()

# %%
sns.boxplot(x='Pclass', y='Age', hue='Sex', data=data, palette='Set2')
plt.title('Distribuição de Idades por Classe e Sexo')
plt.xlabel('Classe')
plt.ylabel('Idade')
plt.legend(title='Sexo', loc='upper right')
plt.show()

# %%
corr = data.corr()  # Calcula a matriz de correlação
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Mapa de Calor das Correlações')
plt.show()

# %% [markdown]
# ## Distribuição de Classes:
#
# Em qual classe havia mais passageiros?
# Isso pode influenciar outros fatores, como sobrevivência?
# Idade vs. Tarifa:
#
# Passageiros mais jovens ou mais velhos pagaram tarifas mais altas?
# Há algum padrão de correlação?
# Distribuição de Idades:
#
# Qual é a faixa etária mais comum entre os passageiros?
# Sobrevivência por Sexo:
#
# Homens ou mulheres tiveram maior probabilidade de sobreviver?
# Algum padrão interessante emerge?
# Idade por Classe:
#
# Passageiros de primeira classe eram mais velhos ou mais jovens que os de classes inferiores?
# Correlação entre Variáveis (Heatmap):
#
# Existe alguma relação forte entre variáveis, como Pclass e Fare ou Age e 2urvived?

# %% [markdown]
# ## Análise Exploratória de Dados
# - **Distribuição de Classes:** A maioria dos passageiros estava na terceira classe.
# - **Idade vs. Tarifa:** Passageiros mais velhos pagaram tarifas mais altas.
# - **Distribuição de Idades:** A faixa etária mais comum era entre 20 e 40 anos.
# - **Sobrevivência por Sexo:** Mulheres tiveram maior probabilidade de sobreviver.
# - **Idade por Classe:** Passageiros da primeira classe eram, em média, mais velhos.
# - **Mapa de Calor:** A variável `Pclass` tem forte correlação com `Fare`.
